# %% [markdown]
# <a href="https://colab.research.google.com/github/yaozin/analise_dados/blob/main/Vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conexão com supabase

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 38.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Configurações extraídas do seu painel
USER = "postgres.cyiohalqxbddaukrewtb"
PASSWORD = "TPEIuuQgpeqWDj73" # Coloque sua senha real aqui
HOST = "aws-1-sa-east-1.pooler.supabase.com"
PORT = "6543"
DB_NAME = "postgres"

# 2. Montando a URL oficial para o SQLAlchemy (com o driver postgresql://)
# O ?sslmode=require é essencial para o Google Colab aceitar a conexão
DB_URL = f"postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}?sslmode=require"

# 3. Criando a engine de conexão
engine = create_engine(DB_URL)

try:
    # 4. Teste de fogo: Puxando as primeiras 5 linhas da dim_customers no schema gold
    query = "SELECT * FROM gold.dim_customers LIMIT 5"
    df = pd.read_sql(query, engine)

    print("✅ CONEXÃO ESTABELECIDA COM SUCESSO!")
    print("-" * 30)
    print(df)

except Exception as e:
    print("❌ A conexão falhou. Verifique se a senha está correta.")
    print(f"Erro detalhado: {e}")
# Out:
# ✅ CONEXÃO ESTABELECIDA COM SUCESSO!
# ------------------------------
#    customer_key  customer_id customer_number first_name last_name    country  \
# 0             1        11000      AW00011000        Jon      Yang  Australia
# 1             2        11001      AW00011001     Eugene     Huang  Australia
# 2             3        11002      AW00011002      Ruben    Torres  Australia
# 3             4        11003      AW00011003    Christy       Zhu  Australia
# 4             5        11004      AW00011004  Elizabeth   Johnson  Australia
#
#   marital_status  gender   birthdate create_date
# 0        Married    Male  1971-10-06  2025-10-06
# 1         Single    Male  1976-05-10  2025-10-06
# 2        Married    Male  1971-02-09  2025-10-06
# 3         Single  Female  1973-08-14  2025-10-06
# 4         Single  Female  1979-08-05  2025-10-06

# %%
# Exemplo: Puxar as vendas para análise
query = "SELECT * FROM gold.fact_sales"

df_vendas = pd.read_sql(query, engine)

# Agora você tem um DataFrame do Pandas pronto para matemática e ciência de dados!
print(f"Total de registros importados: {len(df_vendas)}")
df_vendas.head()
# Out:
# Total de registros importados: 60398
#   order_number  product_key  customer_key  order_date shipping_date  \
# 0      SO54496          282          5400  2013-03-16    2013-03-23
# 1      SO54496          289          5400  2013-03-16    2013-03-23
# 2      SO54496          259          5400  2013-03-16    2013-03-23
# 3      SO54497          174          9281  2013-03-16    2013-03-23
# 4      SO54497          280          9281  2013-03-16    2013-03-23
#
#      due_date  sales_amount  quantity  price
# 0  2013-03-28            25         1     25
# 1  2013-03-28             5         1      5
# 2  2013-03-28             2         1      2
# 3  2013-03-28            22         1     22
# 4  2013-03-28             9         1      9
